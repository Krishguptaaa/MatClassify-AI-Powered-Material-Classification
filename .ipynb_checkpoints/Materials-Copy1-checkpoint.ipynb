# %% [markdown]
# # DATA ANALYSIS

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Data.csv")

df
# Out:
#        Std                                ID             Material  \
# 0     ANSI  D8894772B88F495093C43AF905AB6373       Steel SAE 1015
# 1     ANSI  05982AC66F064F9EBC709E7A4164613A       Steel SAE 1015
# 2     ANSI  356D6E63FF9A49A3AB23BF66BAC85DC3       Steel SAE 1015
# 3     ANSI  1C758F8714AC4E0D9BD8D8AE1625AECD       Steel SAE 1020
# 4     ANSI  DCE10036FC1946FC8C9108D598D116AD       Steel SAE 1020
# ...    ...                               ...                  ...
# 1547   JIS  512A80EC21EA416BA2725B38BA8096EF    Nodular cast iron
# 1548   JIS  38526441BA8741CA979DBF870D0B8A9B    Nodular cast iron
# 1549   JIS  CAC03D7EB1AA45E68EFF92A2EF4C3D9B    Nodular cast iron
# 1550   JIS  45C82A36EC644F8BB6170A99ED819B62  Malleable cast iron
# 1551   JIS  BC74F870412F4DDBADDEF1063C1C079F  Malleable cast iron
#
#      Heat treatment  ultimate tensile strength yeild strength  \
# 0         as-rolled                        421            314
# 1        normalized                        424            324
# 2          annealed                        386            284
# 3         as-rolled                        448            331
# 4        normalized                        441            346
# ...             ...                        ...            ...
# 1547            NaN                        600            370
# 1548            NaN                        700            420
# 1549            NaN                        800            480
# 1550            NaN                        400            180
# 1551            NaN                        500            260
#
#       elongation at break  brinell hardness number  elastic modulus  \
# 0                    39.0                    126.0           207000
# 1                    37.0                    121.0           207000
# 2                    37.0                    111.0           207000
# 3                    36.0                    143.0           207000
# 4                    35.8                    131.0           207000
# ...                   ...                      ...              ...
# 1547                  NaN                      NaN           169000
# 1548                  NaN                      NaN           169000
# 1549                  NaN                      NaN           169000
# 1550                  4.0                      NaN           160000
# 1551                  4.0                      NaN           160000
#
#       shear modulus  poissons ratio  density     pH                 Desc  \
# 0             79000            0.30     7860    NaN                  NaN
# 1             79000            0.30     7860    NaN                  NaN
# 2             79000            0.30     7860    NaN                  NaN
# 3             79000            0.30     7860    NaN                  NaN
# 4             79000            0.30     7860  550.0                  NaN
# ...             ...             ...      ...    ...                  ...
# 1547          70000            0.20     7160  480.0    Nodular cast iron
# 1548          70000            0.20     7160  560.0    Nodular cast iron
# 1549          70000            0.20     7160  600.0    Nodular cast iron
# 1550          64000            0.27     7160  300.0  Malleable cast iron
# 1551          64000            0.27     7160  370.0  Malleable cast iron
#
#          HV
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 1547  210.0
# 1548  230.0
# 1549  240.0
# 1550  220.0
# 1551  230.0
#
# [1552 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1552 entries, 0 to 1551
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Std                        1552 non-null   object
#  1   ID                         1552 non-null   object
#  2   Material                   1552 non-null   object
#  3   Heat treatment             802 non-null    object
#  4   ultimate tensile strength  1552 non-null   int64
#  5   yeild strength             1552 non-null   object
#  6   elongation at break        1346 non-null   float64
#  7   brinell hardness number    463 non-null    float64
#  8   elastic modulus            1552 non-null   int64
#  9   shear modulus              1552 non-null   int64
#  10  poissons ratio             1552 non-null   float64
#  11  density                    1552 non-null   int64
#  12  pH                         193 non-null    float64
#  13  Desc                       981 non-null    object
#  14  HV                         165 non-null    float64
# dtypes: float64(5), int64(4), object(6)
# memory usage: 182.0+ KB

# %%
df.isnull().sum()
# Out:
# Std                             0
# ID                              0
# Material                        0
# Heat treatment                750
# ultimate tensile strength       0
# yeild strength                  0
# elongation at break           206
# brinell hardness number      1089
# elastic modulus                 0
# shear modulus                   0
# poissons ratio                  0
# density                         0
# pH                           1359
# Desc                          571
# HV                           1387
# dtype: int64

# %%
sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
plt.title("Missing Values Heatmap")
plt.show()

# %% [markdown]
# # Since "HV" "pH" "Brinell hardness number" & "Heat Treatment" has very high amount of missing values compared to the size of the dataset, it's better to remove them completely

# %%
df=df.drop(columns=["Heat treatment","brinell hardness number","pH","HV"])
df
# Out:
#        Std                                ID             Material  \
# 0     ANSI  D8894772B88F495093C43AF905AB6373       Steel SAE 1015
# 1     ANSI  05982AC66F064F9EBC709E7A4164613A       Steel SAE 1015
# 2     ANSI  356D6E63FF9A49A3AB23BF66BAC85DC3       Steel SAE 1015
# 3     ANSI  1C758F8714AC4E0D9BD8D8AE1625AECD       Steel SAE 1020
# 4     ANSI  DCE10036FC1946FC8C9108D598D116AD       Steel SAE 1020
# ...    ...                               ...                  ...
# 1547   JIS  512A80EC21EA416BA2725B38BA8096EF    Nodular cast iron
# 1548   JIS  38526441BA8741CA979DBF870D0B8A9B    Nodular cast iron
# 1549   JIS  CAC03D7EB1AA45E68EFF92A2EF4C3D9B    Nodular cast iron
# 1550   JIS  45C82A36EC644F8BB6170A99ED819B62  Malleable cast iron
# 1551   JIS  BC74F870412F4DDBADDEF1063C1C079F  Malleable cast iron
#
#       ultimate tensile strength yeild strength  elongation at break  \
# 0                           421            314                 39.0
# 1                           424            324                 37.0
# 2                           386            284                 37.0
# 3                           448            331                 36.0
# 4                           441            346                 35.8
# ...                         ...            ...                  ...
# 1547                        600            370                  NaN
# 1548                        700            420                  NaN
# 1549                        800            480                  NaN
# 1550                        400            180                  4.0
# 1551                        500            260                  4.0
#
#       elastic modulus  shear modulus  poissons ratio  density  \
# 0              207000          79000            0.30     7860
# 1              207000          79000            0.30     7860
# 2              207000          79000            0.30     7860
# 3              207000          79000            0.30     7860
# 4              207000          79000            0.30     7860
# ...               ...            ...             ...      ...
# 1547           169000          70000            0.20     7160
# 1548           169000          70000            0.20     7160
# 1549           169000          70000            0.20     7160
# 1550           160000          64000            0.27     7160
# 1551           160000          64000            0.27     7160
#
#                      Desc
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 1547    Nodular cast iron
# 1548    Nodular cast iron
# 1549    Nodular cast iron
# 1550  Malleable cast iron
# 1551  Malleable cast iron
#
# [1552 rows x 11 columns]

# %% [markdown]
# since the feature "elongation at break" only has a small percentage of missing values we'll apply median imputation to replace them.

# %%
df["elongation at break"] = df["elongation at break"].fillna(df["elongation at break"].median())
df.isnull().sum()
df
# Out:
#        Std                                ID             Material  \
# 0     ANSI  D8894772B88F495093C43AF905AB6373       Steel SAE 1015
# 1     ANSI  05982AC66F064F9EBC709E7A4164613A       Steel SAE 1015
# 2     ANSI  356D6E63FF9A49A3AB23BF66BAC85DC3       Steel SAE 1015
# 3     ANSI  1C758F8714AC4E0D9BD8D8AE1625AECD       Steel SAE 1020
# 4     ANSI  DCE10036FC1946FC8C9108D598D116AD       Steel SAE 1020
# ...    ...                               ...                  ...
# 1547   JIS  512A80EC21EA416BA2725B38BA8096EF    Nodular cast iron
# 1548   JIS  38526441BA8741CA979DBF870D0B8A9B    Nodular cast iron
# 1549   JIS  CAC03D7EB1AA45E68EFF92A2EF4C3D9B    Nodular cast iron
# 1550   JIS  45C82A36EC644F8BB6170A99ED819B62  Malleable cast iron
# 1551   JIS  BC74F870412F4DDBADDEF1063C1C079F  Malleable cast iron
#
#       ultimate tensile strength yeild strength  elongation at break  \
# 0                           421            314                 39.0
# 1                           424            324                 37.0
# 2                           386            284                 37.0
# 3                           448            331                 36.0
# 4                           441            346                 35.8
# ...                         ...            ...                  ...
# 1547                        600            370                 16.0
# 1548                        700            420                 16.0
# 1549                        800            480                 16.0
# 1550                        400            180                  4.0
# 1551                        500            260                  4.0
#
#       elastic modulus  shear modulus  poissons ratio  density  \
# 0              207000          79000            0.30     7860
# 1              207000          79000            0.30     7860
# 2              207000          79000            0.30     7860
# 3              207000          79000            0.30     7860
# 4              207000          79000            0.30     7860
# ...               ...            ...             ...      ...
# 1547           169000          70000            0.20     7160
# 1548           169000          70000            0.20     7160
# 1549           169000          70000            0.20     7160
# 1550           160000          64000            0.27     7160
# 1551           160000          64000            0.27     7160
#
#                      Desc
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 1547    Nodular cast iron
# 1548    Nodular cast iron
# 1549    Nodular cast iron
# 1550  Malleable cast iron
# 1551  Malleable cast iron
#
# [1552 rows x 11 columns]

# %% [markdown]
# **Since desc is a text column which is unneccesary for k-means we'll remove that as well**

# %%
df=df.drop(columns=["Desc"])

# %%
df.hist(figsize=(12,8),bins=30)
plt.tight_layout()
plt.show()

# %% [markdown]
# *Since features "ID","std" and "material" are categorical, they're not much usefull for clustering hence we'll be dropping them as well*

# %%
df=df.drop(columns=["ID","Material","Std"])
df.head()
# Out:
#    ultimate tensile strength yeild strength  elongation at break  \
# 0                        421            314                 39.0
# 1                        424            324                 37.0
# 2                        386            284                 37.0
# 3                        448            331                 36.0
# 4                        441            346                 35.8
#
#    elastic modulus  shear modulus  poissons ratio  density
# 0           207000          79000             0.3     7860
# 1           207000          79000             0.3     7860
# 2           207000          79000             0.3     7860
# 3           207000          79000             0.3     7860
# 4           207000          79000             0.3     7860

# %% [markdown]
# *Since the "yeild strength" feature had been classified as object we need to transform it to float so it can used for numerical feature analysis*

# %%
df['yeild strength'] = df['yeild strength'].str.replace(' max', '', regex=False).astype(float)

df
# Out:
#       ultimate tensile strength  yeild strength  elongation at break  \
# 0                           421           314.0                 39.0
# 1                           424           324.0                 37.0
# 2                           386           284.0                 37.0
# 3                           448           331.0                 36.0
# 4                           441           346.0                 35.8
# ...                         ...             ...                  ...
# 1547                        600           370.0                 16.0
# 1548                        700           420.0                 16.0
# 1549                        800           480.0                 16.0
# 1550                        400           180.0                  4.0
# 1551                        500           260.0                  4.0
#
#       elastic modulus  shear modulus  poissons ratio  density
# 0              207000          79000            0.30     7860
# 1              207000          79000            0.30     7860
# 2              207000          79000            0.30     7860
# 3              207000          79000            0.30     7860
# 4              207000          79000            0.30     7860
# ...               ...            ...             ...      ...
# 1547           169000          70000            0.20     7160
# 1548           169000          70000            0.20     7160
# 1549           169000          70000            0.20     7160
# 1550           160000          64000            0.27     7160
# 1551           160000          64000            0.27     7160
#
# [1552 rows x 7 columns]

# %% [markdown]
# # Now we're left with our cleaned dataset with useful features. we'll now be using heatmap for visualisation and scaling the columns for better results

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.select_dtypes(include=["number"]).corr(), annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
# scaling the dataset
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(df)

X_scaled_df = pd.DataFrame(X_scaled, columns=df.columns)

print(X_scaled_df.head())
# Out:
#    ultimate tensile strength  yeild strength  elongation at break  \
# 0                  -0.464461       -0.252291             1.730999
# 1                  -0.455279       -0.217736             1.558867
# 2                  -0.571583       -0.355958             1.558867
# 3                  -0.381824       -0.193547             1.472802
# 4                  -0.403248       -0.141713             1.455588
#
#    elastic modulus  shear modulus  poissons ratio   density
# 0         0.756067       -0.05267       -0.121096  0.439896
# 1         0.756067       -0.05267       -0.121096  0.439896
# 2         0.756067       -0.05267       -0.121096  0.439896
# 3         0.756067       -0.05267       -0.121096  0.439896
# 4         0.756067       -0.05267       -0.121096  0.439896

# %% [markdown]
# *To apply PCA t-SNE we should first handle outliers in the dataset through IQR method*

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
df = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %% [markdown]
# # Applying PCA and t-SNE

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Reduce to 2D for visualization
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# Plot
plt.figure(figsize=(8,6))
plt.scatter(X_pca[:,0], X_pca[:,1], s=50, alpha=0.7)
plt.xlabel("PCA Component 1")
plt.ylabel("PCA Component 2")
plt.title("PCA 2D Visualization")
plt.show()

# %%
from sklearn.manifold import TSNE

# Reduce to 2D
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X_scaled)

# Plot
plt.figure(figsize=(8,6))
plt.scatter(X_tsne[:,0], X_tsne[:,1], s=50, alpha=0.7)
plt.xlabel("t-SNE 1")
plt.ylabel("t-SNE 2")
plt.title("t-SNE 2D Visualization")
plt.show()

# %% [markdown]
# # Making our model using k-means as the pca plot dosent show clear dense regions for us to use DBSCAN, hence we'll use k means

# %% [markdown]
# *importing necessary libraries*

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %% [markdown]
# *using silhouette score analysis for finding optimal number of K*

# %%
# Calculate silhouette score for a range of k values
silhouette_scores = []
k_range = range(2, 11) # k from 2 to 10

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init='auto')
    labels = kmeans.fit_predict(X_pca)
    score = silhouette_score(X_pca, labels)
    silhouette_scores.append(score)
    print(f"For k = {k}, Silhouette Score = {score:.4f}")

# Plot the silhouette scores
plt.figure(figsize=(10, 6))
plt.plot(k_range, silhouette_scores, 'bx-')
plt.xlabel('Number of clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score for different k')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=7.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=7.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=7.
#   warnings.warn(
# For k = 2, Silhouette Score = 0.5521
# For k = 3, Silhouette Score = 0.5043
# For k = 4, Silhouette Score = 0.4755
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=7.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=7.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=7.
#   warnings.warn(
# For k = 5, Silhouette Score = 0.4696
# For k = 6, Silhouette Score = 0.4819
# For k = 7, Silhouette Score = 0.4972
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=7.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=7.
#   warnings.warn(
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=7.
#   warnings.warn(
# For k = 8, Silhouette Score = 0.4786
# For k = 9, Silhouette Score = 0.4662
# For k = 10, Silhouette Score = 0.4900

# %% [markdown]
# *from analysis we can see silhouette score is highest for k=2*

# %%
# Apply K-Means with k=2
optimal_k = 2
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init='auto')
kmeans_labels = kmeans.fit_predict(X_pca)

# Get the cluster centers
cluster_centers = kmeans.cluster_centers_
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=7.
#   warnings.warn(

# %% [markdown]
# # visualising our clusters

# %%
# Create a scatter plot of the PCA data, colored by the K-Means labels
plt.figure(figsize=(10, 8))

# Scatter plot for each cluster
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=kmeans_labels, cmap='viridis', s=50, alpha=0.8)

# Plot the cluster centers
plt.scatter(cluster_centers[:, 0], cluster_centers[:, 1], c='red', marker='X', s=200, label='Centroids')

plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.title(f'K-Means Clustering (k={optimal_k}) on PCA-Reduced Data')
plt.legend()
plt.colorbar(scatter, label='Cluster Label')
plt.show()

# %%
final_score = silhouette_score(X_pca, kmeans_labels)
print(f"Final Silhouette Score for k={optimal_k}: {final_score:.4f}")
# Out:
# Final Silhouette Score for k=2: 0.5521

# %% [markdown]
# # Our model is finally complete with highly accurate clusters.
#
# # This file contains data analysis, cleaning, visualisation with PCA, t-SNE and finally model building and evaluation
